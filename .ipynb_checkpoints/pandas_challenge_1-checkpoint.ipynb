# %%
# Import Dependencies
import pandas as pd

# %%
# import the data from the .csv file 
client_data = 'Resources/client_dataset.csv'

# %%
# Read the data file with the Pandas library by creating a new dataframe
client_df=pd.read_csv(client_data)
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54639 entries, 0 to 54638
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   first        54639 non-null  object
#  1   last         54639 non-null  object
#  2   job          54639 non-null  object
#  3   phone        54639 non-null  object
#  4   email        54639 non-null  object
#  5   client_id    54639 non-null  int64
#  6   order_id     54639 non-null  int64
#  7   order_date   54639 non-null  object
#  8   order_week   54639 non-null  int64
#  9   order_year   54639 non-null  int64
#  10  item_id      54639 non-null  object
#  11  category     54639 non-null  object
#  12  subcategory  54639 non-null  object
#  13  unit_price   54639 non-null  float64
#  14  unit_cost    54639 non-null  float64
#  15  unit_weight  54639 non-null  float64
#  16  qty          54639 non-null  int64
#  17  line_number  54639 non-null  int64
# dtypes: float64(3), int64(6), object(9)
# memory usage: 7.5+ MB

# %%
# View the records of the data
## Data contains 54,639 rows and 18 columns
'All columns seem to be populated with no missing information'
client_df
client_df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# 1     201.442.4543x942    myers.t.6537@ferguson-johnson.net      37609
# 2    687.737.9424x8503                swatson8146@payne.net      57113
# 3     827-788-8123x012               bakernathan@benson.com      46554
# 4         265-829-3643  christinaschwartz9252@mcconnell.com      92089
# 5           5016915923             jessica.reyes@grimes.net      33615
# 6  +1-893-400-2733x982          moore.official@martinez.com      87213
# 7   605.947.9467x66513        wright.jesus.7579@meadows.com      46709
# 8     665-955-0156x926                 rbrown850@lewis.info      73362
# 9   (231)342-7216x1421                  ggarcia@bentley.biz      58789
#
#    order_id  order_date  order_week  order_year         item_id     category  \
# 0   8953482  2023-04-28          17        2023  EUD29711-63-6U        decor
# 1   8069089  2023-05-19          20        2023  XDA18116-89-4A  consumables
# 2   1902144  2023-01-29           4        2023  ABE59463-05-7E     software
# 3   9031802  2023-04-25          17        2023  ZMM00836-65-0C  consumables
# 4   1322274  2023-05-28          21        2023  BZX55559-12-3X  consumables
# 5   1327730  2023-05-02          18        2023  BMB23158-88-9A        decor
# 6   8080280  2023-04-19          16        2023  UAC50632-25-4E  consumables
# 7   8946782  2023-02-14           7        2023  UEU25316-01-1U  consumables
# 8   9394118  2023-05-13          19        2023  DDA06248-98-7Z  consumables
# 9   9665852  2023-04-14          15        2023  DUU85042-87-5E    furniture
#
#           subcategory  unit_price  unit_cost  unit_weight  qty  line_number
# 0            wall art     1096.80     762.71         7.50  105            1
# 1                pens       24.95      15.09         1.49   21            0
# 2  project management       13.52       7.86         1.68   39            6
# 3                pens       36.42      24.85         1.23   29            3
# 4                misc      195.10     108.17        46.43   20            1
# 5              plants      172.84     154.44         2.79   78            0
# 6    kitchen supplies      245.56     231.95         1.73   56            5
# 7                pens       20.99      16.97         5.12   22            4
# 8      paper products       83.86      59.00         0.27   49            3
# 9             seating       66.88      54.15         2.47   78            1

# %%
#Use the describe function to gather some basic statistics
client_df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# min        0.010000      0.000000  0.000000e+00      0.000000
# 25%       14.840000      1.450000  3.200000e+01      1.000000
# 50%       49.890000      3.240000  6.800000e+01      3.000000
# 75%      125.570000      6.890000  1.700000e+02      5.000000
# max      846.270000     46.430000  3.958244e+06      9.000000

# %%
# Cleaning the dataset to remove records where the unit weight =0 or quantity=0 
# Both theose fields have mins of 0 and for an order they cannot be 0 as it is assumed client must have these two fields populated
' the below step removed 142 rows where either the unit weight or the quantity is 0'
client_df_clean = client_df.loc[(client_df['unit_weight']>0) | (client_df['qty']>0)]
client_df_clean
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# 0         harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1        myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                    swatson8146@payne.net      57113   1902144  2023-01-29
# 3                   bakernathan@benson.com      46554   9031802  2023-04-25
# 4      christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
# ...                                    ...        ...       ...         ...
# 54634   late_reese_4081@montoya-chavez.org      29043   9021716  2023-04-26
# 54635         derrick.moore.2602@pope.info      41908   6290153  2023-02-08
# 54636            gutierrezm3195@morris.org      35176   8692622  2023-03-05
# 54637            solomonwanda5962@ross.org      24485   7592730  2023-01-18
# 54638                     belld@galvan.com      24007   7489403  2023-01-04
#
#        order_week  order_year         item_id     category  \
# 0              17        2023  EUD29711-63-6U        decor
# 1              20        2023  XDA18116-89-4A  consumables
# 2               4        2023  ABE59463-05-7E     software
# 3              17        2023  ZMM00836-65-0C  consumables
# 4              21        2023  BZX55559-12-3X  consumables
# ...           ...         ...             ...          ...
# 54634          17        2023  UCA28532-31-0B     software
# 54635           6        2023  EBD29277-23-7U  consumables
# 54636           9        2023  EBD30093-55-9Z  consumables
# 54637           3        2023  XMZ38239-49-3D    furniture
# 54638           1        2023  ZCZ05589-50-5D     software
#
#               subcategory  unit_price  unit_cost  unit_weight   qty  \
# 0                wall art     1096.80     762.71         7.50   105
# 1                    pens       24.95      15.09         1.49    21
# 2      project management       13.52       7.86         1.68    39
# 3                    pens       36.42      24.85         1.23    29
# 4                    misc      195.10     108.17        46.43    20
# ...                   ...         ...        ...          ...   ...
# 54634           logistics       83.13      51.60         2.25    33
# 54635    kitchen supplies      206.59     175.46        11.70    47
# 54636   bathroom supplies       65.66      57.31         4.16   475
# 54637              stands        1.48       1.22        18.04   112
# 54638  project management        3.01       1.61         2.07  1031
#
#        line_number
# 0                1
# 1                0
# 2                6
# 3                3
# 4                1
# ...            ...
# 54634            8
# 54635            0
# 54636            6
# 54637            0
# 54638            5
#
# [54639 rows x 18 columns]

# %%
#What three item categories had the most entries?
## find how many entries each category has
category_count= client_df_clean["category"].value_counts()
category_count
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# decor           7954
# electronics     2832
# Name: count, dtype: int64

# %%
## Print out the top 3 categories with the most entries
category_count.head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
#For the category with the most entries, which subcategory had the most entries
## check the total count of sub categories
subcategory_count= client_df_clean["subcategory"].value_counts()
subcategory_count
# Out:
# subcategory
# bathroom supplies     6424
# paper products        5874
# kitchen supplies      5746
# tables                4540
# misc                  4286
# stands                4201
# accounting            3756
# project management    3522
# plants                3466
# wall art              3093
# seating               2664
# pens                  2603
# logistics             1122
# telecom                978
# audio visual           732
# cabling                655
# desks                  510
# computers              467
# Name: count, dtype: int64

# %%
# Creating a new data frame to hold the consumables sub category  and its values
consumables_subcategory = client_df_clean.loc[client_df_clean['category']=='consumables','subcategory'].value_counts()
consumables_subcategory
# Printing out the subcategory with the most entries
consumables_subcategory.head(1)
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
#Which five clients had the most entries in the data?
top_5_clients = client_df_clean['client_id'].value_counts().head(5)
top_5_entries_clientids = top_5_clients.index.tolist()
print(top_5_entries_clientids)
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
#How many total units (the qty column) did the client with the most entries order?
# check how many entries the client_id =33615 has
max_client_units = client_df_clean.loc[client_df_clean['client_id']== 33615,'qty'].sum()
client_id_max= top_5_clients.index[0]
print(f"The top client {client_id_max} has {max_client_units} units ordered")
# Out:
# The top client 33615 has 64313 units ordered

# %%
#Create a column that calculates the subtotal for each line using the unit_price and the qty.
## Creating the column 'subtotal that equals the unit price* the qty of each entry
"got a'SettingwithCopy Warning error here and had to correct it using .loc to define the new variable"

client_df_clean.loc[:,'subtotal'] = client_df_clean['unit_price']* client_df_clean['qty']
#client_df_clean['subtotal']= client_df_clean['subtotal'].map('{:,.2f}'.format)
client_df_clean.sort_values('subtotal')
# Out:
#          first        last                                    job  \
# 49749    Haley        Gill                           Town planner
# 33195   Joseph       Joyce                 Audiological scientist
# 21090   Daniel      Bowman                          Archaeologist
# 39209  Stephen      Bender     Logistics and distribution manager
# 33731    Sarah  Richardson    Exhibitions officer, museum/gallery
# ...        ...         ...                                    ...
# 11740   Lauren       Jones                              Architect
# 25972      Amy     Stewart              Psychologist, educational
# 23929  Michele    Mcdonald  Emergency planning/management officer
# 15112   Dennis     Hawkins    Social research officer, government
# 21801    Julie    Anderson                    Exhibition designer
#
#                         phone                            email  client_id  \
# 49749            626.999.2055       gillh2641@coffey-hess.info      61935
# 33195  001-786-572-5868x34668    joseph.joyce.9673@johnson.biz      94475
# 21090    001-716-757-9724x862        danielbowman@thompson.com      72892
# 39209      953-372-4847x28064   benders7551@johnson-morris.org      14881
# 33731              2056834802  richardsonsmile4695@merritt.com      79361
# ...                       ...                              ...        ...
# 11740            785-820-6323   jones.security.7283@gibson.com      84344
# 25972      979.793.4884x57205           stewartamy@francis.com      86721
# 23929      435-931-4939x95137    mcdonaldm317@hess-jackson.com      38473
# 15112   001-214-888-5838x7410      hawkins.dennis.5195@lee.com      85931
# 21801              5933099462    anderson_better_4704@bell.biz      78965
#
#        order_id  order_date  order_week  order_year  ... unit_weight      qty  \
# 49749   3350005  2023-01-02           1        2023  ...        2.34        0
# 33195   9905931  2023-03-28          13        2023  ...       16.90        0
# 21090   6514417  2023-05-17          20        2023  ...        0.24        0
# 39209   6274838  2023-01-02           1        2023  ...       12.42        0
# 33731   3370363  2023-04-19          16        2023  ...        7.50        0
# ...         ...         ...         ...         ...  ...         ...      ...
# 11740   7071092  2023-03-13          11        2023  ...        1.28   389960
# 25972   6057452  2023-03-21          12        2023  ...        9.22   977121
# 23929   4594154  2023-03-02           9        2023  ...        2.25   219645
# 15112   7263857  2023-03-05           9        2023  ...        2.21   637318
# 21801   3833568  2023-04-29          17        2023  ...        0.09  3958244
#
#       line_number      subtotal  total_weight  shipping_price  \
# 49749           4  0.000000e+00          0.00            0.00
# 33195           7  0.000000e+00          0.00            0.00
# 21090           6  0.000000e+00          0.00            0.00
# 39209           6  0.000000e+00          0.00            0.00
# 33731           4  0.000000e+00          0.00            0.00
# ...           ...           ...           ...             ...
# 11740           4  8.245314e+07     499148.80      3494041.60
# 25972           3  9.810295e+07    9009055.62     63063389.34
# 23929           5  1.482472e+08     494201.25      3459408.75
# 15112           3  2.061214e+08    1408472.78      9859309.46
# 21801           1  5.844743e+08     356241.96      2493693.72
#
#        total_price_without_st  total_price_with_st    total_cost  total_profit
# 49749            0.000000e+00         0.000000e+00  0.000000e+00  0.000000e+00
# 33195            0.000000e+00         0.000000e+00  0.000000e+00  0.000000e+00
# 21090            0.000000e+00         0.000000e+00  0.000000e+00  0.000000e+00
# 39209            0.000000e+00         0.000000e+00  0.000000e+00  0.000000e+00
# 33731            0.000000e+00         0.000000e+00  0.000000e+00  0.000000e+00
# ...                       ...                  ...           ...           ...
# 11740            8.594718e+07         9.389730e+07  7.025909e+07  1.568809e+07
# 25972            1.611663e+08         1.760742e+08  1.344421e+08  2.672426e+07
# 23929            1.517066e+08         1.657395e+08  1.282309e+08  2.347566e+07
# 15112            2.159807e+08         2.359589e+08  1.270239e+08  8.895685e+07
# 21801            5.869680e+08         6.412625e+08  3.987535e+08  1.882145e+08
#
# [54639 rows x 25 columns]

# %%
#Create a column for shipping price. Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
' Additional Assumptions'
' Assumming the unit_weight is in pounds'

# define a function to caclulate shipping price based on weight

def shipping_price(weight):
    if weight >50:
        shipping_price=7*weight
    else:
        shipping_price=10*weight
    return shipping_price

# Creating a total weight variable based on the order's unit weight and quantity
client_df_clean.loc[:,'total_weight'] = client_df_clean['unit_weight']*client_df_clean['qty']

# applying the function to calculate the shipping price based on the total weight
client_df_clean.loc[:,'shipping_price'] = client_df_clean['total_weight'].apply(shipping_price)
client_df_clean.sort_values(by ='total_weight', ascending=False)
#client_df_clean.sort_values(by ='total_weight')
# Out:
#            first       last                                       job  \
# 25972        Amy    Stewart                 Psychologist, educational
# 12597     Jordan      Price                  Local government officer
# 50048     Amanda    Burnett                           Records manager
# 40161    Charles  Mccormick  Conservation officer, historic buildings
# 29737    William     Savage                         Minerals surveyor
# ...          ...        ...                                       ...
# 37356     Robert   Schwartz                               Chiropodist
# 38650  Christine   Anderson             Restaurant manager, fast food
# 16586       Sara   Reynolds              Administrator, Civil Service
# 42775    Heather        Day                Regulatory affairs officer
# 48209     Alyssa   Martinez                 Education officer, museum
#
#                         phone                                email  client_id  \
# 25972      979.793.4884x57205               stewartamy@francis.com      86721
# 12597            687.750.2141          pricej@donaldson-garcia.com      62227
# 50048      (959)858-6180x6708            evidence.amanda@clark.biz      77354
# 40161   001-667-790-6949x2885    mccormick_sign@potter-sanford.com      46571
# 29737            534.689.6772            savagewilliam@johnson.com      30339
# ...                       ...                                  ...        ...
# 37356            616.860.7115     appear.schwartz.5096@miller.info      39516
# 38650              2042205251  christine.anderson.3349@holland.org      77875
# 16586  001-469-273-8963x37933                   reynoldss@lamb.net      81576
# 42775       (251)730-3328x301                      dayh@hughes.net      43607
# 48209            440-527-7555          a.martinez.218@thompson.com      47752
#
#        order_id  order_date  order_week  order_year  ...     category  \
# 25972   6057452  2023-03-21          12        2023  ...    furniture
# 12597   3989744  2023-01-23           4        2023  ...  consumables
# 50048   3089707  2023-04-17          16        2023  ...  consumables
# 40161   1553623  2023-05-22          21        2023  ...    furniture
# 29737   9375270  2023-02-14           7        2023  ...  consumables
# ...         ...         ...         ...         ...  ...          ...
# 37356   9094247  2023-02-20           8        2023  ...  consumables
# 38650   6826459  2023-05-26          21        2023  ...  consumables
# 16586   9154147  2023-02-04           5        2023  ...  consumables
# 42775   2132988  2023-01-11           2        2023  ...     software
# 48209   6999579  2023-05-12          19        2023  ...  consumables
#
#             subcategory unit_price  unit_cost  unit_weight     qty  \
# 25972            tables     100.40      73.05         9.22  977121
# 12597    paper products     229.74     198.38        27.51  212123
# 50048  kitchen supplies      81.23      69.22         6.64  494692
# 40161           seating      99.45      60.07        23.49  127184
# 29737    paper products     229.74     198.38        27.51  100479
# ...                 ...        ...        ...          ...     ...
# 37356    paper products      82.57      59.42         0.00     687
# 38650    paper products      82.57      59.42         0.00      39
# 16586    paper products      82.57      59.42         0.00       6
# 42775        accounting     237.30     125.04        19.13       0
# 48209    paper products      82.57      59.42         0.00     174
#
#        line_number     subtotal  total_weight  shipping_price
# 25972            3  98102948.40    9009055.62     63063389.34
# 12597            6  48733138.02    5835503.73     40848526.11
# 50048            1  40183831.16    3284754.88     22993284.16
# 40161            6  12648448.80    2987552.16     20912865.12
# 29737            7  23084045.46    2764177.29     19349241.03
# ...            ...          ...           ...             ...
# 37356            3     56725.59          0.00            0.00
# 38650            1      3220.23          0.00            0.00
# 16586            1       495.42          0.00            0.00
# 42775            3         0.00          0.00            0.00
# 48209            6     14367.18          0.00            0.00
#
# [54639 rows x 21 columns]

# %%
#Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%.
'Sales tax applies to both total price and the shipping price but cannot be used to calculate profit-hence crating 2 columns'
'total_price_without_st= subtotal+ shipping price to be used in profit calculation '
'total_price_with_sales_tax to be used to compute the total spend of a client '

client_df_clean.loc[:,"total_price_without_st"] =(client_df_clean['subtotal']) + (client_df_clean['shipping_price'])
client_df_clean.loc[:,"total_price_with_st"] =(1 + 0.0925)*((client_df_clean['subtotal'])+ (client_df_clean['shipping_price']))
client_df_clean
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# 0         harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1        myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                    swatson8146@payne.net      57113   1902144  2023-01-29
# 3                   bakernathan@benson.com      46554   9031802  2023-04-25
# 4      christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
# ...                                    ...        ...       ...         ...
# 54634   late_reese_4081@montoya-chavez.org      29043   9021716  2023-04-26
# 54635         derrick.moore.2602@pope.info      41908   6290153  2023-02-08
# 54636            gutierrezm3195@morris.org      35176   8692622  2023-03-05
# 54637            solomonwanda5962@ross.org      24485   7592730  2023-01-18
# 54638                     belld@galvan.com      24007   7489403  2023-01-04
#
#        order_week  order_year  ... unit_price unit_cost unit_weight   qty  \
# 0              17        2023  ...    1096.80    762.71        7.50   105
# 1              20        2023  ...      24.95     15.09        1.49    21
# 2               4        2023  ...      13.52      7.86        1.68    39
# 3              17        2023  ...      36.42     24.85        1.23    29
# 4              21        2023  ...     195.10    108.17       46.43    20
# ...           ...         ...  ...        ...       ...         ...   ...
# 54634          17        2023  ...      83.13     51.60        2.25    33
# 54635           6        2023  ...     206.59    175.46       11.70    47
# 54636           9        2023  ...      65.66     57.31        4.16   475
# 54637           3        2023  ...       1.48      1.22       18.04   112
# 54638           1        2023  ...       3.01      1.61        2.07  1031
#
#        line_number   subtotal  total_weight  shipping_price  \
# 0                1  115164.00        787.50         5512.50
# 1                0     523.95         31.29          312.90
# 2                6     527.28         65.52          458.64
# 3                3    1056.18         35.67          356.70
# 4                1    3902.00        928.60         6500.20
# ...            ...        ...           ...             ...
# 54634            8    2743.29         74.25          519.75
# 54635            0    9709.73        549.90         3849.30
# 54636            6   31188.50       1976.00        13832.00
# 54637            0     165.76       2020.48        14143.36
# 54638            5    3103.31       2134.17        14939.19
#
#        total_price_without_st  total_price_with_st
# 0                   120676.50        131839.076250
# 1                      836.85           914.258625
# 2                      985.92          1077.117600
# 3                     1412.88          1543.571400
# 4                    10402.20         11364.403500
# ...                       ...                  ...
# 54634                 3263.04          3564.871200
# 54635                13559.03         14813.240275
# 54636                45020.50         49184.896250
# 54637                14309.12         15632.713600
# 54638                18042.50         19711.431250
#
# [54639 rows x 23 columns]

# %%
#Create a column for the cost of each line using unit cost, qty, and shipping price 
' Assumption: Shipping cost is the same as what is charged to the client'
client_df_clean.loc[:,"total_cost"] = (client_df_clean["unit_cost"]*client_df_clean["qty"]) + (client_df_clean["shipping_price"])
client_df_clean
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# 0         harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1        myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                    swatson8146@payne.net      57113   1902144  2023-01-29
# 3                   bakernathan@benson.com      46554   9031802  2023-04-25
# 4      christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
# ...                                    ...        ...       ...         ...
# 54634   late_reese_4081@montoya-chavez.org      29043   9021716  2023-04-26
# 54635         derrick.moore.2602@pope.info      41908   6290153  2023-02-08
# 54636            gutierrezm3195@morris.org      35176   8692622  2023-03-05
# 54637            solomonwanda5962@ross.org      24485   7592730  2023-01-18
# 54638                     belld@galvan.com      24007   7489403  2023-01-04
#
#        order_week  order_year  ... unit_cost unit_weight   qty  line_number  \
# 0              17        2023  ...    762.71        7.50   105            1
# 1              20        2023  ...     15.09        1.49    21            0
# 2               4        2023  ...      7.86        1.68    39            6
# 3              17        2023  ...     24.85        1.23    29            3
# 4              21        2023  ...    108.17       46.43    20            1
# ...           ...         ...  ...       ...         ...   ...          ...
# 54634          17        2023  ...     51.60        2.25    33            8
# 54635           6        2023  ...    175.46       11.70    47            0
# 54636           9        2023  ...     57.31        4.16   475            6
# 54637           3        2023  ...      1.22       18.04   112            0
# 54638           1        2023  ...      1.61        2.07  1031            5
#
#         subtotal  total_weight  shipping_price  total_price_without_st  \
# 0      115164.00        787.50         5512.50               120676.50
# 1         523.95         31.29          312.90                  836.85
# 2         527.28         65.52          458.64                  985.92
# 3        1056.18         35.67          356.70                 1412.88
# 4        3902.00        928.60         6500.20                10402.20
# ...          ...           ...             ...                     ...
# 54634    2743.29         74.25          519.75                 3263.04
# 54635    9709.73        549.90         3849.30                13559.03
# 54636   31188.50       1976.00        13832.00                45020.50
# 54637     165.76       2020.48        14143.36                14309.12
# 54638    3103.31       2134.17        14939.19                18042.50
#
#        total_price_with_st  total_cost
# 0            131839.076250    85597.05
# 1               914.258625      629.79
# 2              1077.117600      765.18
# 3              1543.571400     1077.35
# 4             11364.403500     8663.60
# ...                    ...         ...
# 54634          3564.871200     2222.55
# 54635         14813.240275    12095.92
# 54636         49184.896250    41054.25
# 54637         15632.713600    14280.00
# 54638         19711.431250    16599.10
#
# [54639 rows x 24 columns]

# %%
#Create a column for the profit of each line using line cost and line price.
' Assumes Sales tax is only applied to the customer and cannot be included in the profit '
client_df_clean.loc[:,"total_profit"] = client_df_clean["total_price_without_st"] - client_df_clean["total_cost"]
client_df_clean
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# 0         harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1        myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                    swatson8146@payne.net      57113   1902144  2023-01-29
# 3                   bakernathan@benson.com      46554   9031802  2023-04-25
# 4      christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
# ...                                    ...        ...       ...         ...
# 54634   late_reese_4081@montoya-chavez.org      29043   9021716  2023-04-26
# 54635         derrick.moore.2602@pope.info      41908   6290153  2023-02-08
# 54636            gutierrezm3195@morris.org      35176   8692622  2023-03-05
# 54637            solomonwanda5962@ross.org      24485   7592730  2023-01-18
# 54638                     belld@galvan.com      24007   7489403  2023-01-04
#
#        order_week  order_year  ... unit_weight   qty line_number   subtotal  \
# 0              17        2023  ...        7.50   105           1  115164.00
# 1              20        2023  ...        1.49    21           0     523.95
# 2               4        2023  ...        1.68    39           6     527.28
# 3              17        2023  ...        1.23    29           3    1056.18
# 4              21        2023  ...       46.43    20           1    3902.00
# ...           ...         ...  ...         ...   ...         ...        ...
# 54634          17        2023  ...        2.25    33           8    2743.29
# 54635           6        2023  ...       11.70    47           0    9709.73
# 54636           9        2023  ...        4.16   475           6   31188.50
# 54637           3        2023  ...       18.04   112           0     165.76
# 54638           1        2023  ...        2.07  1031           5    3103.31
#
#        total_weight  shipping_price  total_price_without_st  \
# 0            787.50         5512.50               120676.50
# 1             31.29          312.90                  836.85
# 2             65.52          458.64                  985.92
# 3             35.67          356.70                 1412.88
# 4            928.60         6500.20                10402.20
# ...             ...             ...                     ...
# 54634         74.25          519.75                 3263.04
# 54635        549.90         3849.30                13559.03
# 54636       1976.00        13832.00                45020.50
# 54637       2020.48        14143.36                14309.12
# 54638       2134.17        14939.19                18042.50
#
#        total_price_with_st  total_cost  total_profit
# 0            131839.076250    85597.05      35079.45
# 1               914.258625      629.79        207.06
# 2              1077.117600      765.18        220.74
# 3              1543.571400     1077.35        335.53
# 4             11364.403500     8663.60       1738.60
# ...                    ...         ...           ...
# 54634          3564.871200     2222.55       1040.49
# 54635         14813.240275    12095.92       1463.11
# 54636         49184.896250    41054.25       3966.25
# 54637         15632.713600    14280.00         29.12
# 54638         19711.431250    16599.10       1443.40
#
# [54639 rows x 25 columns]

# %%
#Confirm Your Work
check_ids =[2742071,2173913,6128929]
for id in check_ids:
    check_order = client_df_clean.loc[client_df_clean["order_id"]==id,"total_price_with_st"].sum()
    check_order_fin = '{:,.2f}'.format(check_order)
    print(f" for order id {id} Total price with sales tax and shipping charges is : ${check_order_fin}")
# Out:
#  for order id 2742071 Total price with sales tax and shipping charges is : $152,811.90
#  for order id 2173913 Total price with sales tax and shipping charges is : $162,388.72
#  for order id 6128929 Total price with sales tax and shipping charges is : $923,441.24

# %%
#How much did each of the top 5 clients by quantity spend? Use your work from Part 1 for client ids
'Top 5 clients by entries are contained in the list top_5_entries_clientids'
' top 5 ids by qty are different from ids by entries calculated in part 1 - using top 5 ids with the most entries,
'- from part 1, for this step'
' The below analysis assumes total revenue is the total price * quantity , contained in the column subtotal'

# check below was to confirm if top 5 by quantity were the same as top5 by entries
#top_5_byqty = client_df_clean.groupby(['client_id'])['qty'].sum()
#top_5_byqty.sort_values(ascending=False)
# check complete 


# 

print(top_5_entries_clientids)
# Define a function to convert dollars to millions
def millions(value):
    return value / 1000000

#Define the empty lists for spend and total summary for top 5
top5_clients_spend = []
for client_id in top_5_entries_clientids:
    top_5_spend = client_df_clean.loc[client_df_clean["client_id"]==client_id,"total_price_with_st"].sum()
    
# formatting the output to show units and dollars 
    top_5_spend_fin = '${:,.2f}'.format(top_5_spend_mm)
    
    
    row={ 'client id': client_id,
           'Total Spend (total cost+shipping+slaes tax)': top_5_spend_fin
         }
    top5_clients_spend.append(row)
                             
top5_summ_spend=pd.DataFrame(top5_clients_spend)
top5_summ_spend
# Out:
# [33615, 66037, 46820, 38378, 24741]
#    client id Total Spend (total cost+shipping+slaes tax)
# 0      33615                                8,377,308.57
# 1      66037                               10,259,514.80
# 2      46820                                9,743,794.32
# 3      38378                               12,906,550.88
# 4      24741                               82,268,891.98

# %%
#Create a summary DataFrame showing the totals for the top 5 clients with the following information: total units purchased, total shipping price, total revenue, and total profit.

# check below was to confirm if top 5 by quantity were the same as top5 by entries
#top_5_byqty = client_df_clean.groupby(['client_id'])['qty'].sum()
#top_5_byqty.sort_values(ascending=False)
# check complete 


# 

print(top_5_entries_clientids)
# Define a function to convert dollars to millions
def millions(value):
    return value / 1000000

#Define the empty lists for spend and total summary for top 5
top5_clients_spend = []
top5_summary = []
for client_id in top_5_entries_clientids:
    top_5_units = client_df_clean.loc[client_df_clean["client_id"]==client_id,"qty"].sum()
    top_5_ship = client_df_clean.loc[client_df_clean["client_id"]==client_id,"shipping_price"].sum.apply(milllions)
    top_5_spend = client_df_clean.loc[client_df_clean["client_id"]==client_id,"total_price_with_st"].sum()
    top_5_cost = client_df_clean.loc[client_df_clean["client_id"]==client_id,"total_cost"].sum()
    top_5_rev = client_df_clean.loc[client_df_clean["client_id"]==client_id,"subtotal"].sum()
    top_5_profit = client_df_clean.loc[client_df_clean["client_id"]==client_id,"total_profit"].sum()

    
# formatting the output to show units and dollars 
    top_5_units_fin = '{:,.0f}'.format(top_5_units)
    top_5_ship_fin = '${:,.2f}'.format(top_5_ship_mm)
    top_5_spend_fin = '${:,.2f}'.format(top_5_spend_mm)
    top_5_cost_fin = '${:,.2f}'.format(top_5_cost_mm)
    top_5_profit_fin = '${:,.2f}'.format(top_5_profit_mm)
    
    
    row={ 'client id': client_id,
           'Total Spend (total cost+shipping+slaes tax)': top_5_spend_fin
         }
    top5_clients_spend.append(row)
                             
top5_summ_spend=pd.DataFrame(top5_clients_spend)
top5_summ_spend
